# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from sklearn.cluster import KMeans
from numpy.random import RandomState
import numpy as np

rng = RandomState(42)

# %%
from itertools import cycle

def plot_2D(data,target,target_names):
    colors = cycle('rgbcmykw')
    target_ids = range(len(target_names))
    plt.figure()
    
    for i,c,label in zip(target_ids,colors,target_names):
        plt.scatter(data[target==i,0],data[target==i,1], c=c,label=label)
    plt.legend()

# %%
from IPython.core.display import Image,display

filename = 'C:\Users\Mayank\Desktop\Python\iris_versicolor.jpg'

# %%
display(Image(filename))

# %%
print "Iris Versicolor\n"

filename1='C:\Users\Mayank\Desktop\Python\iris_virginica.jpg'
display(Image(filename1))
print"Iris Virginica"

filename2='C:\Users\Mayank\Desktop\Python\iris_setosa.jpg'
display(Image(filename2))
print"Iris Setosa"
# Out:
# Iris Versicolor
# Iris Virginica
# Iris Setosa

# %%
from sklearn.datasets import load_iris
iris = load_iris()

X = iris.data   #features
Y = iris.target #class labels

print iris.target_names
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
plot_2D(X,Y,iris.target_names)

# %%
kmeans = KMeans(n_clusters=3,random_state=rng)
kmeans.fit(X)

np.round(kmeans.cluster_centers_,decimals=2)

kmeans.labels_

plot_2D(X,kmeans.labels_,["c0","c1","c2"])
plot_2D(X,Y,iris.target_names)

# %%
print X.shape
# Out:
# (150L, 4L)

# %%
from sklearn import decomposition 
import numpy as np 
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA

pca = decomposition.PCA() #generate PCA model

pca = PCA(n_components=2, whiten=False) 
pca.fit(X)
X_pca = pca.transform(X)
print X_pca.shape

#since we want only 2 components, use first 2 parts of eigen values
# Out:
# (150L, 2L)

# %%
kmeans = KMeans(n_clusters=3,random_state=rng)
kmeans.fit(X_pca)

np.round(kmeans.cluster_centers_,decimals=2)

kmeans.labels_

plot_2D(X_pca,kmeans.labels_,["c0","c1","c2"])
plot_2D(X,Y,iris.target_names)
